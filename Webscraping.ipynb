# %%
# import important library

import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# Fetc
URL = "https://realpython.github.io/fake-jobs/"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
soup

# %%
results=soup.find(id='ResultsContainer')

# %%
results.prettify()
job_elements=results.find_all('div', class_="card-content")

# %%
job_elements

# %%
list_title=[]
list_company=[]
list_location=[]
list_posting_date=[]

for job_element in job_elements:
  title=job_element.find('h2',class_="title").text.strip()
  company=job_element.find('h3',class_="subtitle").text.strip()
  location=job_element.find('p',class_="location").text.strip()
  posting_date=job_element.find('time').text.strip()
  list_title.append(title)
  list_company.append(company)
  list_location.append(location)
  list_posting_date.append(posting_date)

# %%
df=pd.DataFrame({"Job Title":list_title,"Company Name":list_company,"Location":list_location,"Posting Date":list_posting_date})

# %%
df
# Out:
#                              Job Title                Company Name  \
# 0              Senior Python Developer    Payne, Roberts and Davis
# 1                      Energy engineer            Vasquez-Davidson
# 2                      Legal executive  Jackson, Chambers and Levy
# 3               Fitness centre manager              Savage-Bradley
# 4                      Product manager                 Ramirez Inc
# ..                                 ...                         ...
# 95  Museum/gallery exhibitions officer     Nguyen, Yoder and Petty
# 96            Radiographer, diagnostic                  Holder LLC
# 97              Database administrator              Yates-Ferguson
# 98                  Furniture designer             Ortega-Lawrence
# 99                         Ship broker   Fuentes, Walls and Castro
#
#                 Location Posting Date
# 0        Stewartbury, AA   2021-04-08
# 1   Christopherville, AA   2021-04-08
# 2    Port Ericaburgh, AA   2021-04-08
# ...

# %%
df.to_csv('/content/webscrap_jobs.csv')
